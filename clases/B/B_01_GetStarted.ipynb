# %% [markdown]
# <div>
# <h1>Inicio</h1>
# </div>
#
# <p>
# Este cuaderno brinda una breve introduccion acerca de como comenzar a interactuar con los cuadernos FMP.
# </p>

# %% [markdown]
# A fin de ejecutar las celdas de codigo Python, necesitamos disponer de los cuadernos juntamente con los datos, crear un entorno, y lanzar un servidor Jupyter. A continuacion, explicamos los siguientes pasos en detalle:
#
# * Descargar los cuadernos FMP y datos requeridos
# * Instalar Miniconda
# * Crear un entorno empleando conda
# * Lanzar el servidor Jupyter

# %% [markdown]
# ## Descarga de los cuadernos
#
# Los cuadernos FMP y datos requeridos (archivos de audio, imagen y video) se encuentran contenidos en el archivo comprimido `clases.zip` accesible desde
# <div class="alert alert-block alert-warning">
# <a href="https://drive.google.com/file/d/1f7huO01bqtOP3JBkpx2BNPWd8utspD6B/view?usp=sharing">repositorio drive del seminario</a>
# </div>
#
# Descomprima el archivo y almacenelo en su PC local.

# %% [markdown]
# ## Instalacion de Miniconda
#
# [Conda](https://conda.io/docs/) es un sistema de gestión de paquetes de código abierto el cual instala, ejecuta y actualiza rápidamente los paquetes y sus dependencias. El mismo corre en Windows, macOS and Linux. El paquete Conda se incluye en **Anaconda** y en su version minima **Miniconda**. Este ultimo permite instalar Python, Jupyter y todas las librerias requeridas por el curso.
#
# Descargue e instale la version de Miniconda acorde a su sistema operativo desde el siguiente sitio web:
# <div class="alert alert-block alert-warning">
# <a href="https://docs.conda.io/en/latest/miniconda.html">sitio Miniconda</a>
# </div>

# %% [markdown]
# ## Creacion del entorno FMP
#
# Proveemos un archivo de entorno el cual presenta una lista con todos los paquetes requeridos para interactuar con los cuadernos FMP. Abra una ventana de comandos en Windows o terminal en Linux/macOS. Desde el directorio que contiene el archivo de entorno `environment.yml` ejecute lo siguiente:
# <div class="alert alert-block alert-warning">
# <tt>conda env create -f environment.yml</tt>
# </div>

# %% [markdown]
# ## Lanzamiento del servidor Jupyter
#
# A continuacion, activamos el entorno (*ambiente*) FMP con el siguiente comando:
#
# <div class="alert alert-block alert-warning">
# <tt>conda activate FMP</tt>
# </div>
#
# Finalmente, desde el directorio que contiene los cuadernos FMP
# ejecute lo siguiente para abrir una sesión de Jupyter en su navegador web:
#
# <div class="alert alert-block alert-warning">
# <tt>jupyter notebook</tt>
# </div>
#
# Este comando permitira mostrar la estructura de los cuadernos FMP. Asi, sera posible abrir cualquier cuaderno FMP seleccionando un archivo con la extension `.ipynb`.

# %% [markdown]
# ## Resumen de comandos utiles
#
# A continuacion se exhibe una lista de comandos que resultan de ayuda al momento de actualizar y lanzar el entorno FMP.
#
# <div class="alert alert-block alert-warning">
#
# <tt>
# conda update conda <br>
# conda env update -f environment.yml <br>
# conda env remove -n FMP <br>
# conda env create -f environment.yml <br>
#
# conda activate FMP <br>
# nbstripout --install <br>
# jupyter notebook<br>
#
# jupyter contrib nbextension install --user <br>
# jupyter nbextension enable spellchecker/main
# </tt>
#
# <tt>
# jupyter notebook --NotebookApp.disable_check_xsrf=True
# </tt>
#
# </div>

# %% [markdown]
# ## StackOverflow
# Constituye un sitio web de referencia para la busqueda de preguntas y respuestas sobre *Python*, *NumPy* y *Matplotlib* por medio de palabras clave en los siguientes enlaces:
#
# * [python](https://stackoverflow.com/questions/tagged/python)
# * [numpy](https://stackoverflow.com/questions/tagged/numpy)
# * [matplotlib](https://stackoverflow.com/questions/tagged/matplotlib)

# %%
from IPython.core.display import HTML
css_file = '.././styles/numericalmoocstyle.css'
HTML(open(css_file, 'r').read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <link href='https://fonts.googleapis.com/css?family=Source+Code+Pro' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
# ...
