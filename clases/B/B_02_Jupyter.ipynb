# %% [markdown]
# # Cuadernos Jupyter

# %% [markdown]
# ## ¿Qué es Jupyter?
# Jupyter es un entorno de trabajo que permite desarrollar codigo en Python (por defecto, aunque veremos como permitir otros lenguajes) de manera dinamica, a la vez que integrar en un mismo documento tanto bloques de codigo como texto, graficos o imagenes. Es utilizado ampliamente en analisis numerico, estadistica y machine learning, entre otros campos de la informatica y la matematica.

# %% [markdown]
# ## Creando un cuaderno
# Podemos arrancar el servidor de cuadernos con el comando
#
# ```Bash
# jupyter notebook
# ```
#
# Se abrira una nueva ventana en nuestro navegador predefinido, y la terminal quedara bloqueada con el proceso. Podemos en forma alternativa abrirlo en otro navegador, para lo cual se nos indica la URL en la salida por pantalla:
#
# ```Bash
# http://localhost:8888/tree
# ```
#
# El workspace que abre Jupyter es nuestro home de usuario. Con el boton New, podemos crear:
# * Carpetas
# * Archivos de texto
# * Terminales
# * Cuadernos
#
# Cuando creamos un cuaderno, se nos abre en una pestaña nueva. La interfaz es muy sencilla, con una barra de menu y herramientas y una celda vacia, que es la unidad basica de trabajo con Jupyter. En una celda, podremos escribir una o varias lineas de codigo, y ejecutarla. Tambien podemos escribir texto plano, y eliminar la celda del flujo de ejecucion del cuaderno o hacer que se muestre de manera diferente si queremos que funcione como titulo, separador de seccion, etc.
#
# Es importante remarcar que tenemos dos modos de trabajo en Jupyter:
#
# * **edicion**, que permite modificar el contenido de las celdas, como si fuera un editor de texto. La que tengamos seleccionada se muestra en verde. Podemos entrar en el mismo seleccionando una celda y pulsando *Enter*.
# <img src='https://imgur.com/burNHbh.png'>
#
# * **mando**, que nos permite ejecutar celdas o modificar el cuaderno y su estructura. La celda seleccionada se muestra en azul. Podemos volver al modo de mando pulsando *Esc*.
# <img src='https://imgur.com/b7I1thD.png'>
#
# Ademas, si ha habido un error en la ejecucion de una celda, esta aparece en color rojo.

# %% [markdown]
# ## Ejecutando codigo
# Para ejecutar una celda, haremos *Shift + Enter*. Para conocer el estado de ejecucion de una celda, podemos mirar la cabecera de la misma:
# * Si solamente aparece `In [ ]`, quiere decir que aun no se ha ejecutado.
# * Si lo que tenemos es `In [\*]`, entonces esta en proceso de ejecucion.
# * Si aparece un numero entre los corchetes, ya ha terminado de ejecutar.
#
# <img src="../data/B/runandprint.gif" width="500" align="center">
#
# ### Sobre-escribir el valor de una variable
# Puesto que cada celda interactua en la misma instancia Python, si asignamos un nuevo valor para una variable `x` y luego corremos `print(x)` tendremos en pantalla aquel nuevo valor. Si luego eliminamos la celda en la cual asignamos el nuevo valor a `x`, la asignacion nueva (`x=7`) continua siendo valida. De hecho, la asignacion permanecera valida hasta que en forma explicita ejecutemos una celda la cual asigne a `x` un nuevo valor.
#
# <img src="../data/B/overwrite.gif" width="500" align="center">

# %% [markdown]
# ## Escribiendo texto
# Aspectos a tener en cuenta durante la escritura de texto plano:
# * Se debe indicar que el tipo de celda es **Markdown**.
#
# <img src="../data/B/rendermarkdown.gif" width="500" align="center">
#
# * Podemos separar el contenido del documento con cabeceras para secciones, subsecciones, subsubsecciones, etc. Se logra añadiendo de una a cinco veces el simbolo `#` al principio de la linea, tantas como el nivel que queramos tenga el titulo.
# <img width=400px src='https://imgur.com/eIlgGHr.png'>
#
# * Para mostrar codigo $\LaTeX$ en nuestro cuaderno, simplemente tenemos que escribir entre signos `$...$` y marcar la celda como texto plano (Markdown).
#
# <img src="../data/B/mathjax.gif" width="500" align="center">
#
# * Entre las referencias para aprender trucos de sintaxis **Markdown**, recomendamos el resumen de [John Gruber](https://daringfireball.net/projects/markdown/syntax).

# %% [markdown]
# ## Trucos extra
# A menudo se requiere agregar o borrar celdas, o unicamente moverlas a traves del cuaderno. Para mover una celda, haga click en la misma para seleccionarla, y luego utilize las flechas disponibles en la barra de herramientas para cambiar la posicion de la celda.
#
# <img src="../data/B/movingcells.gif" width="500" align="center">
#
# Para agregar una celda, puede hacer click en el boton `+` de la barra de herramientas.

# %%
from IPython.core.display import HTML
css_file = '.././styles/numericalmoocstyle.css'
HTML(open(css_file, 'r').read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <link href='https://fonts.googleapis.com/css?family=Source+Code+Pro' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
# ...
